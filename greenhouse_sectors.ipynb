# %%
# %matplotlib notebook

# %%
import warnings
warnings.filterwarnings('ignore')

# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import gmaps
import os
import datetime

# %%
# Read in csv file
sector_data = pd.read_csv("/Users/brianastaples/Project_01/greenhouse_gas_emmissions_by_sector.csv")
sector_data
# Out:
#           Economic Sector         2018
# 0          Transportation  1882.557612
# 1  Electricity generation  1798.925112
# 2                Industry  1470.743037
# 3             Agriculture   658.556550
# 4              Commercial   443.321738
# 5             Residential   375.919063
# 6        U.S. territories    46.626504

# %%
plt.pie(sector_data['2018'], labels=sector_data.iloc[:,0], autopct="%1.1f%%")

plt.axis("equal")
plt.savefig("/Users/brianastaples/Project_01/greenhouse.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %%
# Title: U.S. Greenhouse Gas Emissions
#     Emmissions in million metric tons of carbon dioxide equivalents

# https://cfpub.epa.gov/
