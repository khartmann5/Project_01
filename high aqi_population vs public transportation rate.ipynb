# %%
import requests
import os
import gmaps
import datetime 
import pandas as pd
import numpy as np
from scipy.stats import linregress
from matplotlib import pyplot as plt

# %%
city_data = pd.read_csv("Resources/Collected_Pollution_Measurements.csv")
city_data.head()
# Out:
#               datetime      co     no    no2     o3    so2  pm2_5   pm10  \
# 0  2021-01-31 12:00:00  781.06  38.89  87.74   0.09  23.60  35.14  45.48
# 1  2021-01-31 11:00:00  534.06   5.87  78.14   4.47  20.98  18.22  24.25
# 2  2021-01-31 10:00:00  460.63   1.36  67.86  13.23  20.03  13.65  18.51
# 3  2021-01-31 09:00:00  447.27   0.83  63.75  15.38  19.07  12.76  17.30
# 4  2021-01-31 08:00:00  447.27   0.82  61.69  15.02  17.17  12.64  16.99
#
#      nh3  aqi      City  Public Transportation Rate  Median Age  Population
# 0  10.89  4.0  Brooklyn                    61.84046   34.694286   2480847.0
# 1   6.33  2.0  Brooklyn                    61.84046   34.694286   2480847.0
# 2   5.07  2.0  Brooklyn                    61.84046   34.694286   2480847.0
# 3   4.75  2.0  Brooklyn                    61.84046   34.694286   2480847.0
# 4   4.69  2.0  Brooklyn                    61.84046   34.694286   2480847.0

# %%
city_data["City"].unique()
# Out:
# array(['Brooklyn', 'Chicago', 'Houston', 'Las Vegas', 'Los Angeles',
#        'Manhattan', 'Miami', 'Philadelphia', 'San Antonio', 'San Diego',
#        'Artesia', 'East Lansing', 'CRYSTAL CITY', 'Yardley',
#        'Fort Washington', 'DORCHESTR CTR', 'Peabody', 'Marshfield',
#        'Somerset', 'Belmont', 'Hoboken', 'Glendora', 'Oregon City',
#        'Denton', 'Southeast Washington', 'Christiana', 'Cathedral City',
#        'Kaneohe', 'Lombard', 'Rancho Cordova', 'Lithonia', 'Revere',
#        'Issaquah', 'Syracuse', 'Placentia', 'Kailua', 'Eagle Mountain',
#        'Santa Monica', 'E RNCHO DMNGZ', 'Bolingbrook', 'Union',
#        'Mill Creek', 'Romansville', 'Oxford', 'Blacksburg', 'Perth Amboy',
#        'Canóvanas', 'Irvington', 'Blaine', 'Mililani', 'Hazard', 'Normal',
#        'Boulder', 'Briarwood', 'Bowie', 'Willowbrook', 'Biscayne Park',
#        'Paramount', 'Waterbury', 'Upper Gwynedd', 'Wayne', 'Dundalk',
#        'Norcross', 'Lompoc', 'Hacienda Heights', 'Jackson Township',
#        'West Haven', 'Schenectady', 'Eddington', 'Mount Prospect',
#        'North Massapequa', 'Freehold', 'Plainview',
#        'Northeast Washington', 'Oak Lawn', 'South Hempstead',
#        'St. Charles', 'Ozone Park', 'West Springfield', 'Piscataway',
#        'Garrison', 'Bremerton', 'Swansea', 'Ames', 'North Charleston',
#        'Chicago Heights', 'Whitehall', 'Deer Park', 'Bothell',
#        'Spring Valley', 'Gilroy', 'SIENNA PLANT', 'Annandale',
#        'Jackson Heights', 'Long Island City', 'Woodside', 'West Bronx',
#        'East Flatbush', 'Forest Hills', 'The Bronx', 'Rego Park',
#        'New York', 'East Elmhurst', 'Queens', 'East Bronx', 'Jamaica',
#        'Maspeth', 'Jersey City', 'West New York', 'North Philadelphia',
#        'Far Rockaway', 'Northwest Washington', 'Middle Village',
#        'Elmhurst', 'West Philadelphia', 'Joint Base Anacostia-Bolling',
#        'Boston', 'Mid Island', 'Scarsdale', 'San Francisco', 'Flushing',
#        'North Bergen', 'Malden', 'Lenexa', 'Texarkana', 'Valrico',
#        "Coeur d'Alene", 'Twin Falls', 'Westerville', 'Roanoke', 'Dalton',
#        'Rome', 'Salinas', 'Uniontown', 'Mount Pleasant', 'Helena',
#        'Far West Side', 'Hadley', 'Eagle Pass', 'Traverse City',
#        'Centerville', 'Snellville', 'Lodi', 'Lakeland', 'Delano',
#        'Cape Coral', 'Hattiesburg', 'Wichita', 'Pflugerville', 'Baytown',
#        'Boise', 'Gastonia', 'Grand Prairie', 'Tulare', 'Lilburn',
#        'Leander', 'McAllen', 'CARNES CROSSROADS', 'Riverview', 'Altoona',
#        'Woodville', 'Gilbert', 'McMinnville', 'Webster', 'Johnson City',
#        'The Villages', 'Flower Mound', 'Tyler', 'Winchester', 'Clermont',
#        'Lake Forest', 'Mason', 'VLG WELLINGTN', 'Hanford', 'Anderson',
#        'Sun City', 'Hudson', 'Newnan', 'Mooresville', 'Glen Allen',
#        'Lockport', 'Cumming', 'DeLand', 'Cuyahoga Falls', 'Beaumont',
#        'Brighton', 'Bend', 'Bristol', 'Independence', 'Naples', 'Saginaw',
#        'Palm Harbor', 'Victoria', 'Youngstown', 'Arecibo', 'Bay City',
#        'Knoxville', 'Painesville', 'Brunswick', 'Grove City', 'Jackson',
#        'Corinth', 'Harvey', 'Greenville', 'Yuma', 'Omaha',
#        'Elizabethtown', 'Portage', 'Great Falls', 'Lebanon', 'Bessemer',
#        'Westland', 'Cedar Park', 'Odessa', 'Cayey', 'NEW PRT RCHY',
#        'Murfreesboro', 'Augusta', 'Newton', 'Mountain Brook', 'Hollister',
#        'North Ridgeville', 'Dearborn', 'Toledo', 'HUNTINGTN BCH',
#        'Mobile', 'Bradenton', 'Fort Wayne', 'West Chester Township',
#        'Mesquite', 'Palos Verdes Peninsula', 'Abilene', 'Greece',
#        'Rockford', 'Avondale', 'Oro Valley', 'Goldsboro', 'Mount Airy',
#        'Thousand Oaks', 'Erie', 'Tomball', 'Elkhart', 'Aguadilla Pueblo',
#        'Ponce', 'Hilliard', 'MENTOR ON THE', 'Lake Shore', 'Pensacola',
#        'Central Oklahoma City', 'Royal Oak', 'Bozeman', 'Council Bluffs',
#        'Burleson', 'Jonesboro', 'Taylor', 'Virginia Beach',
#        'Colorado Springs', 'Greensburg', 'Oak Glen', 'Vacaville',
#        'Carrollton', 'Brownsville', 'Apopka', 'Merced', 'Goose Creek',
#        'Powder Springs', 'SUGARCRK Township', 'Clarksville', 'Fargo',
#        'Apple Valley', 'Fort Worth', 'McDonough', 'Victorville',
#        'Redding', 'Alpharetta', 'S CHESTERFLD', 'Lawton', 'Lawrenceville',
#        'Suwanee', 'Del Sur', 'Overland Park', 'Matthews'], dtype=object)

# %%
max_aqi = city_data["aqi"].max
max_aqi
# Out:
# <bound method Series.max of 0         4.0
# 1         2.0
# 2         2.0
# 3         2.0
# 4         2.0
#          ...
# 202125    1.0
# 202126    1.0
# 202127    1.0
# 202128    1.0
# 202129    1.0
# Name: aqi, Length: 202130, dtype: float64>

# %%
high_aqi = city_data.sort_values("aqi", ascending=False)
high_aqi
# Out:
#                    datetime       co      no    no2     o3    so2   pm2_5  \
# 24159   2021-01-11 07:00:00   988.01   56.77  97.33   0.00  12.64   53.41
# 71491   2021-01-13 23:00:00  1308.44  135.90  85.68   0.00  16.21   63.95
# 71502   2021-01-13 12:00:00  1441.96  150.20  55.52   0.00  16.21   78.66
# 71501   2021-01-13 13:00:00  2082.82  246.76  67.17   0.00  18.84  120.07
# 71500   2021-01-13 14:00:00  2857.21  368.36  84.31   0.12  23.84  170.71
# ...                     ...      ...     ...    ...    ...    ...     ...
# 86698   2021-01-19 06:00:00   243.66    0.00   7.28  70.81   1.73    0.69
# 86699   2021-01-19 05:00:00   247.00    0.00   8.31  70.10   1.73    0.83
# 86700   2021-01-19 04:00:00   253.68    0.00   9.85  69.38   1.68    1.12
# 86701   2021-01-19 03:00:00   257.02    0.00  10.37  70.10   1.64    1.19
# 202129  2021-01-01 12:00:00   280.38    0.48   8.74   7.87   0.87    4.37
#
#           pm10    nh3  aqi       City  Public Transportation Rate  Median Age  \
# 24159    76.78   5.95  5.0  Placentia                    2.584794   36.400000
# 71491    80.78  10.13  5.0  Rego Park                   58.448699   42.800000
# 71502   104.04  17.73  5.0  Rego Park                   58.448699   42.800000
# 71501   157.80  27.11  5.0  Rego Park                   58.448699   42.800000
# 71500   218.22  36.99  5.0  Rego Park                   58.448699   42.800000
# ...        ...    ...  ...        ...                         ...         ...
# 86698     1.20   0.52  1.0     Boston                   34.485527   33.357143
# 86699     1.46   0.56  1.0     Boston                   34.485527   33.357143
# 86700     1.89   0.64  1.0     Boston                   34.485527   33.357143
# 86701     2.01   0.67  1.0     Boston                   34.485527   33.357143
# 202129    4.66   0.21  1.0   Matthews                    0.998507   40.050000
#
#         Population
# 24159      53474.0
# 71491      41792.0
# 71502      41792.0
# 71501      41792.0
# 71500      41792.0
# ...            ...
# 86698     442696.0
# 86699     442696.0
# 86700     442696.0
# 86701     442696.0
# 202129     72164.0
#
# [202130 rows x 14 columns]

# %%
high_aqi = high_aqi.loc[high_aqi["aqi"] == 5]
high_aqi
# Out:
#                    datetime       co      no     no2     o3    so2   pm2_5  \
# 24159   2021-01-11 07:00:00   988.01   56.77   97.33   0.00  12.64   53.41
# 71491   2021-01-13 23:00:00  1308.44  135.90   85.68   0.00  16.21   63.95
# 71502   2021-01-13 12:00:00  1441.96  150.20   55.52   0.00  16.21   78.66
# 71501   2021-01-13 13:00:00  2082.82  246.76   67.17   0.00  18.84  120.07
# 71500   2021-01-13 14:00:00  2857.21  368.36   84.31   0.12  23.84  170.71
# ...                     ...      ...     ...     ...    ...    ...     ...
# 3406    2021-01-04 18:00:00  2002.72  243.19   91.85   5.01  13.95  103.41
# 162190  2021-01-10 06:00:00  1361.85   26.38  172.73   0.01  10.61   99.26
# 3430    2021-01-03 18:00:00  1441.96  151.99   67.17   5.05   8.82   89.30
# 3427    2021-01-03 21:00:00   700.95   12.63   58.26  80.11  18.84   79.59
# 3407    2021-01-04 17:00:00  1708.98  205.64   76.08   2.03  10.25   84.53
#
#           pm10    nh3  aqi           City  Public Transportation Rate  \
# 24159    76.78   5.95  5.0      Placentia                    2.584794
# 71491    80.78  10.13  5.0      Rego Park                   58.448699
# 71502   104.04  17.73  5.0      Rego Park                   58.448699
# 71501   157.80  27.11  5.0      Rego Park                   58.448699
# 71500   218.22  36.99  5.0      Rego Park                   58.448699
# ...        ...    ...  ...            ...                         ...
# 3406    130.68  10.64  5.0    Los Angeles                   12.176151
# 162190  123.79   8.23  5.0  HUNTINGTN BCH                    0.780783
# 3430    107.46   5.19  5.0    Los Angeles                   12.176151
# 3427     89.17   0.12  5.0    Los Angeles                   12.176151
# 3407    109.24  10.01  5.0    Los Angeles                   12.176151
#
#         Median Age  Population
# 24159    36.400000     53474.0
# 71491    42.800000     41792.0
# 71502    42.800000     41792.0
# 71501    42.800000     41792.0
# 71500    42.800000     41792.0
# ...            ...         ...
# 3406     32.657143   1019978.0
# 162190   44.250000     88481.0
# 3430     32.657143   1019978.0
# 3427     32.657143   1019978.0
# 3407     32.657143   1019978.0
#
# [5714 rows x 14 columns]

# %%
x = high_aqi["Population"]
y = high_aqi["Public Transportation Rate"]

# %%
plt.scatter(x, y, facecolors="green", edgecolors="black")



plt.show()
