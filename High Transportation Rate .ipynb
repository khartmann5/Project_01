# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
city_data = pd.read_csv("Resources/city_pop_transit_age_latlng.csv")
city_data.head()
# Out:
#                 City  Population  Public Transportation Rate  Median Age  \
# 0               ABAC     25590.0                    0.346470       36.90
# 1           Aberdeen     31027.0                    0.362211       36.70
# 2  Aberdeen Township     30709.0                   11.924538       41.70
# 3            Abilene     57336.0                    0.802012       31.45
# 4           Abingdon     29587.0                    1.981002       35.60
#
#          Lat        Lng
# 0  31.483076 -83.530194
# 1  57.149717  -2.094278
# 2  40.417095 -74.222116
# 3  32.448736 -99.733144
# 4  36.709833 -81.977348

# %%
high_transportation = city_data.sort_values("Public Transportation Rate", ascending=False)
high_transportation.head(40)
# Out:
#                               City  Population  Public Transportation Rate  \
# 912                Jackson Heights     63202.0                   71.771714
# 1105              Long Island City    163789.0                   71.090482
# 2236                      Woodside     88939.0                   68.267635
# 2155                    West Bronx    277955.0                   65.549832
# 523                  East Flatbush     77011.0                   63.130525
# 218                      Briarwood     54523.0                   62.715252
# 231                       Brooklyn   2480847.0                   61.840460
# 651                   Forest Hills     69652.0                   61.260193
# 1991                     The Bronx    941062.0                   60.225610
# 1670                     Rego Park     41792.0                   58.448699
# 1162                     Manhattan   1379505.0                   58.244459
# ...

# %%
high_transportation = high_transportation.loc[high_transportation["Public Transportation Rate"] > 30]
high_transportation.count()
# Out:
# City                          38
# Population                    38
# Public Transportation Rate    38
# Median Age                    38
# Lat                           38
# Lng                           38
# dtype: int64

# %%
high_transportation.to_csv("Resources/high_rate.csv", index=False)
