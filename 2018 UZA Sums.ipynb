# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import gmaps
import json
import os

# %%
uza_sums = pd.read_csv("/Users/brianastaples/Project_01/2018 UZA Sums.csv")
uza_sums
# Out:
#      UZA                UZA Name UZA Population Total Vehicle Revenue Miles  \
# 0      0         Alabama Non-UZA            NaN                   5,837,073
# 1      0          Alaska Non-UZA            NaN                   4,072,666
# 2      0  American Samoa Non-UZA            NaN                     147,007
# 3      0         Arizona Non-UZA            NaN                   5,628,984
# 4      0        Arkansas Non-UZA            NaN                  12,331,660
# ..   ...                     ...            ...                         ...
# 536  496        Grand Island, NE         50,440                     156,739
# 537  497          Pascagoula, MS         50,428                      54,569
# 538  600      Virgin Islands, VI        106,405                     514,277
# 539  601       Lake Tahoe, CA-NV        210,000                   1,050,227
# 540  602           Galveston, TX         54,770                     556,126
#
# ...

# %%
reduced_uza_sums = uza_sums[["UZA Name", "Total Unlinked Passenger Trips"]]
reduced_uza_sums
# Out:
#                    UZA Name Total Unlinked Passenger Trips
# 0           Alabama Non-UZA                      1,583,938
# 1            Alaska Non-UZA                      1,954,878
# 2    American Samoa Non-UZA                         26,358
# 3           Arizona Non-UZA                      2,000,611
# 4          Arkansas Non-UZA                      1,000,272
# ..                      ...                            ...
# 536        Grand Island, NE                         37,087
# 537          Pascagoula, MS                          8,702
# 538      Virgin Islands, VI                        327,899
# 539       Lake Tahoe, CA-NV                        879,112
# 540           Galveston, TX                        459,709
#
# [541 rows x 2 columns]

# %%
reduced_uza_sums.set_index('UZA Name').filter(like='Portland', axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-61ce8b8934ff> in <module>
# ----> 1 reduced_uza_sums.set_index('UZA Name').filter(like='Portland', axis=0)
#
# NameError: name 'reduced_uza_sums' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-7f6026c09ffe> in <module>
# ----> 1 reduced_uza_sums.loc[['Portland']]
#       2
#       3 reduced_uza_sums
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# ...
